# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('salary_data_cleaned.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                        Company Name  Founded  \
# 0           0  Raytheon Missiles & Defense\r\n3.8     2020
# 1           1                       Humana\r\n3.9     1961
# 2           2                  AstraZeneca\r\n4.2     1913
# 3           3                  AstraZeneca\r\n4.2     1913
# 4           4                   BankUnited\r\n2.9     2009
#
#                     Industry  \
# 0        Aerospace & Defense
# 1         Insurance Carriers
# 2  Biotech & Pharmaceuticals
# 3  Biotech & Pharmaceuticals
# 4      Banks & Credit Unions
#
#                                      Job Description  \
# 0  Senior Data Scientist\r\nRaytheon Missiles & D...
# 1  Description\r\nDigital Health and Analytics wi...
# 2  Do you have a passion for Science? Would you l...
# 3  Research Scientist/ Senior Research Scientist\...
# 4  Summary: The FCC Analytics group is responsibl...
#
#                                        Job Title          Location  Rating  \
# 0     Senior Data Scientist , Advanced Analytics       Andover, MA     3.8
# 1                               Data Scientist 2    Louisville, KY     3.9
# 2           Scientist - Antibody Drug Conjugates  Gaithersburg, MD     4.2
# 3  Research Scientist/ Senior Research Scientist  Gaithersburg, MD     4.2
# 4                             FCC Data Scientist   Miami Lakes, FL     2.9
#
#               Revenue               Salary Estimate  ... python_yn  \
# 0  $10+ billion (USD)  $123K-$199K (Glassdoor est.)  ...         1
# 1  $10+ billion (USD)    $52K-$95K (Glassdoor est.)  ...         1
# 2  $10+ billion (USD)   $61K-$123K (Glassdoor est.)  ...         0
# 3  $10+ billion (USD)   $88K-$167K (Glassdoor est.)  ...         0
# 4  $10+ billion (USD)   $73K-$121K (Glassdoor est.)  ...         1
#
#   r_studio_yn sql_yn  cloud_yn excel_yn  bigquery_yn  spark_yn  \
# 0           0      0         1        0            0         0
# 1           0      1         0        0            0         1
# 2           0      0         0        0            0         0
# 3           0      0         0        1            0         0
# 4           0      1         0        0            0         0
#
#         job_simpl  seniority desc_len
# 0  data scientist     senior     4667
# 1  data scientist         na     3555
# 2              na         na     4703
# 3              na     senior     5222
# 4  data scientist         na     4843
#
# [5 rows x 32 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Company Name', 'Founded', 'Industry', 'Job Description',
#        'Job Title', 'Location', 'Rating', 'Revenue', 'Salary Estimate',
#        'Sector', 'Size', 'Type of ownership', 'hourly', 'currency',
#        'employer_provided', 'min_salary', 'max_salary', 'average_salary',
#        'company_txt', 'job_region-state', 'age', 'python_yn', 'r_studio_yn',
#        'sql_yn', 'cloud_yn', 'excel_yn', 'bigquery_yn', 'spark_yn',
#        'job_simpl', 'seniority', 'desc_len'],
#       dtype='object')

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
    
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
        return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower() or 'intern' in title.lower() or 'co-op' in title.lower() or 'coop' in title.lower():
        return 'jr'
    else:
        return 'na'

# %% [markdown]
# ## Job title and seniority

# %%
df['job_simpl'] = df['Job Title'].apply(title_simplifier)
df['job_simpl'].value_counts()
# Out:
# data scientist    352
# na                110
# analyst            92
# data engineer      68
# mle                27
# manager             6
# director            3
# Name: job_simpl, dtype: int64

# %%
df['seniority'] = df['Job Title'].apply(seniority)
df['seniority'].value_counts()
# Out:
# na        493
# senior    161
# jr          4
# Name: seniority, dtype: int64

# %% [markdown]
# ## Fix State Los Angeles

# %%
df['job_region-state'].value_counts()
# As we dont have this issue with out dataset so it is left as is.
# Out:
# Toronto          107
#  CA               65
# Vancouver         51
# Montreal          45
#  MD               32
#  VA               27
#  NY               21
#  TX               20
#  MA               16
# Calgary           16
# Ottawa            15
#  DC               13
#  UT               12
#  FL               11
#  GA               10
#  NJ               10
#  PA                9
#  CO                8
#  NC                8
#  OH                8
# Edmonton           8
# Saint-Laurent      7
#  WI                7
# Mississauga        7
#  IN                6
# Winnipeg           6
#  IL                6
#  MO                6
# North York         6
# Oakville           6
#                 ...
# Halifax            3
#  ME                2
# Pointe-Claire      2
# Dartmouth          2
# Burlington         2
# Moncton            2
#  AZ                2
# Cochin             2
# Welwyn             2
# Laval              2
#  ID                2
# Fort St. John      2
#  MI                2
# Quebec             2
# Chatham-Kent       2
#  MS                1
# Vaughan            1
# Venice             1
# Waterloo           1
# Surrey             1
#  SC                1
# Bedford            1
# Kitchener          1
#  KS                1
# Sioux Lookout      1
# Regina             1
# Guelph             1
# Vernon             1
#  AL                1
# Saskatoon          1
# Name: job_region-state, Length: 71, dtype: int64

# %% [markdown]
# ## Job Description Length

# %%
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))
df['desc_len']
# Out:
# 0       4667
# 1       3555
# 2       4703
# 3       5222
# 4       4843
# 5       5598
# 6       6609
# 7       2949
# 8       2972
# 9       4008
# 10      6252
# 11      4441
# 12      2244
# 13      6118
# 14      4771
# 15      4852
# 16      5673
# 17      2473
# 18      2921
# 19      4945
# 20      3535
# 21      3633
# 22      4972
# 23      3265
# 24      5332
# 25      3334
# 26      3775
# 27      3773
# 28      2277
# 29      3681
#        ...
# 628     7581
# 629     9114
# 630     6125
# 631     6283
# 632    10235
# 633     4644
# 634     2920
# 635     3486
# 636     7219
# 637     2711
# 638     6454
# 639     1810
# 640     5114
# 641     4430
# 642     3159
# 643     3522
# 644     4578
# 645    15432
# 646     6974
# 647     3231
# 648     3159
# 649     3522
# 650     4578
# 651     3076
# 652     6974
# 653     4895
# 654     3524
# 655     6283
# 656     4630
# 657     6013
# Name: desc_len, Length: 658, dtype: int64

# %% [markdown]
# ## Competitor count

# %%
#df['num_comp'] = df['Competitors'].apply(lambda x: len(x.split(',')) if x != '-1' else 0)

# %% [markdown]
# ## hourly to annual
#
# It is based on an assumption that on average there are 2000 hours / annum.

# %%
df['min_salary'] = df.apply(lambda x: x.min_salary*2 if x.hourly is 1 else x.min_salary, axis = 1)
df['max_salary'] = df.apply(lambda x: x.max_salary*2 if x.hourly is 1 else x.max_salary, axis = 1)

# %%
df[df.hourly == 1][['hourly', 'min_salary', 'max_salary']]
# Out:
#      hourly  min_salary  max_salary
# 10        1          72         132
# 157       1         188         284
# 182       1         188         284
# 265       1          60         104
# 282       1          28          44
# 297       1          56          80
# 312       1          28          44

# %% [markdown]
# ## Converting CAD to US Dollar for fair comparison
#
# Conversion rate @Date 2020-12-20 = 1 CAD = 0.78 US Dollar

# %%
df['average_salary'] = df.apply(lambda x: x.average_salary*0.78 if x.currency is 'CAD' else x.average_salary, axis = 1)
df['min_salary'] = df.apply(lambda x: x.min_salary*0.78 if x.currency is 'CAD' else x.min_salary, axis = 1)
df['max_salary'] = df.apply(lambda x: x.max_salary*0.78 if x.currency is 'CAD' else x.max_salary, axis = 1)

# %% [markdown]
# ## remove new line from job title

# %%
df['company_txt'] = df.company_txt.apply(lambda x: x.replace('\r', '').replace('\n',''))

# %%
df['company_txt']
# Out:
# 0                         Raytheon Missiles & Defense
# 1                                              Humana
# 2                                         AstraZeneca
# 3                                         AstraZeneca
# 4                                          BankUnited
# 5                                                Unum
# 6                             Farm Credit Mid-America
# 7      Johns Hopkins Applied Physics Laboratory (APL)
# 8                                Myriad Genetics, Inc
# 9                                               GEICO
# 10                                    Trinity Biotech
# 11                                      Tivity Health
# 12                                             Humana
# 13                          Catalent Pharma Solutions
# 14                                              GEICO
# 15                  Intuitive Research and Technology
# 16                                        Benson Hill
# 17                                            Enverus
# 18                             Intelligent Automation
# 19                                            Blucora
# 20                          BioFire Diagnostics, LLC.
# 21                                              Avant
# 22                                         Akima, LLC
# 23                                   Northrop Grumman
# 24                            Laticrete International
# 25                                   Northrop Grumman
# 26                                United Therapeutics
# 27                                            Buckman
# 28           Assured Information Security, Inc. (AIS)
# 29                                            Waystar
#                             ...
# 628                      Renaissance BioScience Corp.
# 629                                        NanoXplore
# 630                    Government of British Columbia
# 631              Provincial Health Services Authority
# 632                                          CAE Inc.
# 633                      Amazon Dev Centre Canada ULC
# 634                                           Uplight
# 635                                             CDLSI
# 636                                ZeniMax Media Inc.
# 637                                          agileDSS
# 638                                             Onica
# 639                                           Aerotek
# 640                                            Kainos
# 641                                      Rocket Homes
# 642                         IT IQ TECH RECRUITERS LTD
# 643                                        O2E Brands
# 644                                 Savormetrics Inc.
# 645                 Sunnybrook Health Sciences Centre
# 646                                          CaseWare
# 647                                      Global Relay
# 648                         IT IQ TECH RECRUITERS LTD
# 649                                        O2E Brands
# 650                                 Savormetrics Inc.
# 651                        SynergyAspen Environmental
# 652                                          CaseWare
# 653            Centre for Addiction and Mental Health
# 654                                            Tucows
# 655              Provincial Health Services Authority
# 656                                           AVANADE
# 657                                            Tecsys
# Name: company_txt, Length: 658, dtype: object

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.describe()
# Out:
#        Unnamed: 0      Founded      Rating      hourly  employer_provided  \
# count  658.000000   658.000000  658.000000  658.000000              658.0
# mean   328.500000  1580.547112    3.505623    0.010638                0.0
# std    190.092521   793.937477    1.283468    0.102670                0.0
# min      0.000000    -1.000000   -1.000000    0.000000                0.0
# 25%    164.250000  1892.000000    3.400000    0.000000                0.0
# 50%    328.500000  1983.500000    3.800000    0.000000                0.0
# 75%    492.750000  2005.000000    4.100000    0.000000                0.0
# max    657.000000  2020.000000    5.000000    1.000000                0.0
#
#        min_salary  max_salary  average_salary         age   python_yn  \
# count  658.000000  658.000000      658.000000  658.000000  658.000000
# mean    74.601824  113.893617       93.340426   33.823708    0.700608
# std     26.364951   40.196181       31.826423   44.560419    0.458340
# min     11.000000   40.000000        9.000000   -1.000000    0.000000
# 25%     57.000000   85.000000       71.000000    4.000000    0.000000
# 50%     72.000000  107.500000       89.500000   18.000000    1.000000
# 75%     89.000000  136.000000      111.750000   43.000000    1.000000
# max    188.000000  284.000000      201.000000  352.000000    1.000000
#
#        r_studio_yn      sql_yn    cloud_yn    excel_yn  bigquery_yn  \
# count    658.00000  658.000000  658.000000  658.000000   658.000000
# mean       0.00304    0.521277    0.313070    0.541033     0.025836
# std        0.05509    0.499927    0.464095    0.498693     0.158766
# min        0.00000    0.000000    0.000000    0.000000     0.000000
# 25%        0.00000    0.000000    0.000000    0.000000     0.000000
# 50%        0.00000    1.000000    0.000000    1.000000     0.000000
# 75%        0.00000    1.000000    1.000000    1.000000     0.000000
# max        1.00000    1.000000    1.000000    1.000000     1.000000
#
#          spark_yn      desc_len
# count  658.000000    658.000000
# mean     0.261398   4276.715805
# std      0.439731   1897.576678
# min      0.000000    145.000000
# 25%      0.000000   3080.250000
# 50%      0.000000   3980.500000
# 75%      1.000000   5168.500000
# max      1.000000  16129.000000

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Company Name', 'Founded', 'Industry', 'Job Description',
#        'Job Title', 'Location', 'Rating', 'Revenue', 'Salary Estimate',
#        'Sector', 'Size', 'Type of ownership', 'hourly', 'currency',
#        'employer_provided', 'min_salary', 'max_salary', 'average_salary',
#        'company_txt', 'job_region-state', 'age', 'python_yn', 'r_studio_yn',
#        'sql_yn', 'cloud_yn', 'excel_yn', 'bigquery_yn', 'spark_yn',
#        'job_simpl', 'seniority', 'desc_len'],
#       dtype='object')

# %%
df.Rating.hist()

# %%
df.average_salary.hist()

# %%
df.age.hist()

# %%
df.job_simpl.hist()

# %%
df.desc_len.hist()

# %%
df.boxplot(column = ['age', 'Rating', 'average_salary'])

# %%
df.boxplot(column = 'Rating')

# %%
df.corr()
# Out:
#                    Unnamed: 0   Founded    Rating    hourly  \
# Unnamed: 0           1.000000 -0.277158 -0.156820 -0.061961
# Founded             -0.277158  1.000000  0.473270  0.015147
# Rating              -0.156820  0.473270  1.000000 -0.017781
# hourly              -0.061961  0.015147 -0.017781  1.000000
# employer_provided         NaN       NaN       NaN       NaN
# min_salary          -0.189052  0.192786  0.193135  0.054985
# max_salary          -0.458772  0.237070  0.198546  0.064448
# average_salary      -0.345910  0.224846  0.209475 -0.211653
# age                 -0.172442  0.343754  0.201475  0.002074
# python_yn           -0.033987  0.093107  0.033397 -0.158627
# r_studio_yn          0.048400 -0.040406  0.010521 -0.005726
# sql_yn               0.001401  0.091868  0.071808 -0.108206
# cloud_yn             0.005831  0.113009  0.101041 -0.006117
# excel_yn             0.039112 -0.004174  0.015215  0.036052
# bigquery_yn         -0.031394  0.085367  0.068752 -0.016887
# spark_yn             0.048235  0.027039  0.052678 -0.061689
# desc_len            -0.027703  0.069352  0.051559  0.104000
#
#                    employer_provided  min_salary  max_salary  average_salary  \
# Unnamed: 0                       NaN   -0.189052   -0.458772       -0.345910
# Founded                          NaN    0.192786    0.237070        0.224846
# Rating                           NaN    0.193135    0.198546        0.209475
# hourly                           NaN    0.054985    0.064448       -0.211653
# employer_provided                NaN         NaN         NaN             NaN
# min_salary                       NaN    1.000000    0.865170        0.896005
# max_salary                       NaN    0.865170    1.000000        0.923821
# average_salary                   NaN    0.896005    0.923821        1.000000
# age                              NaN    0.003221    0.056149        0.026887
# python_yn                        NaN    0.276922    0.205882        0.288356
# r_studio_yn                      NaN   -0.054706   -0.074088       -0.067870
# sql_yn                           NaN    0.150535    0.097594        0.153751
# cloud_yn                         NaN    0.155869    0.136005        0.133228
# excel_yn                         NaN   -0.106764   -0.110792       -0.128235
# bigquery_yn                      NaN    0.114457    0.101079        0.115885
# spark_yn                         NaN    0.164829    0.097418        0.146763
# desc_len                         NaN   -0.031100   -0.026246       -0.054522
#
#                         age  python_yn  r_studio_yn    sql_yn  cloud_yn  \
# Unnamed: 0        -0.172442  -0.033987     0.048400  0.001401  0.005831
# Founded            0.343754   0.093107    -0.040406  0.091868  0.113009
# Rating             0.201475   0.033397     0.010521  0.071808  0.101041
# hourly             0.002074  -0.158627    -0.005726 -0.108206 -0.006117
# employer_provided       NaN        NaN          NaN       NaN       NaN
# min_salary         0.003221   0.276922    -0.054706  0.150535  0.155869
# max_salary         0.056149   0.205882    -0.074088  0.097594  0.136005
# average_salary     0.026887   0.288356    -0.067870  0.153751  0.133228
# age                1.000000  -0.079646    -0.030783 -0.005434 -0.030447
# python_yn         -0.079646   1.000000     0.036095  0.336725  0.212338
# r_studio_yn       -0.030783   0.036095     1.000000  0.052914  0.022257
# sql_yn            -0.005434   0.336725     0.052914  1.000000  0.187735
# cloud_yn          -0.030447   0.212338     0.022257  0.187735  1.000000
# excel_yn           0.132040  -0.056046     0.050856  0.002598 -0.062167
# bigquery_yn       -0.037436   0.085541    -0.008992  0.136888  0.034659
# spark_yn          -0.088373   0.290716     0.029983  0.189298  0.359133
# desc_len           0.176645  -0.043697     0.026770  0.014739  0.158398
#
#                    excel_yn  bigquery_yn  spark_yn  desc_len
# Unnamed: 0         0.039112    -0.031394  0.048235 -0.027703
# Founded           -0.004174     0.085367  0.027039  0.069352
# Rating             0.015215     0.068752  0.052678  0.051559
# hourly             0.036052    -0.016887 -0.061689  0.104000
# employer_provided       NaN          NaN       NaN       NaN
# min_salary        -0.106764     0.114457  0.164829 -0.031100
# max_salary        -0.110792     0.101079  0.097418 -0.026246
# average_salary    -0.128235     0.115885  0.146763 -0.054522
# age                0.132040    -0.037436 -0.088373  0.176645
# python_yn         -0.056046     0.085541  0.290716 -0.043697
# r_studio_yn        0.050856    -0.008992  0.029983  0.026770
# sql_yn             0.002598     0.136888  0.189298  0.014739
# cloud_yn          -0.062167     0.034659  0.359133  0.158398
# excel_yn           1.000000     0.015426 -0.069810  0.225621
# bigquery_yn        0.015426     1.000000  0.033928  0.064864
# spark_yn          -0.069810     0.033928  1.000000  0.046000
# desc_len           0.225621     0.064864  0.046000  1.000000

# %%
df[['age', 'Rating', 'average_salary','desc_len','python_yn','sql_yn','cloud_yn']].corr()
# Out:
#                      age    Rating  average_salary  desc_len  python_yn  \
# age             1.000000  0.201475        0.026887  0.176645  -0.079646
# Rating          0.201475  1.000000        0.209475  0.051559   0.033397
# average_salary  0.026887  0.209475        1.000000 -0.054522   0.288356
# desc_len        0.176645  0.051559       -0.054522  1.000000  -0.043697
# python_yn      -0.079646  0.033397        0.288356 -0.043697   1.000000
# sql_yn         -0.005434  0.071808        0.153751  0.014739   0.336725
# cloud_yn       -0.030447  0.101041        0.133228  0.158398   0.212338
#
#                   sql_yn  cloud_yn
# age            -0.005434 -0.030447
# Rating          0.071808  0.101041
# average_salary  0.153751  0.133228
# desc_len        0.014739  0.158398
# python_yn       0.336725  0.212338
# sql_yn          1.000000  0.187735
# cloud_yn        0.187735  1.000000

# %%
cmap = sns.diverging_palette(120, 20, as_cmap=True)
sns.heatmap(df[['age', 'Rating', 'average_salary','desc_len','python_yn','sql_yn','cloud_yn']].corr(),
            vmax=.3, center = 0, cmap = cmap,
           square = True, linewidth = .5, cbar_kws={'shrink':.5})

# %% [markdown]
# #### Categorial Variables

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Company Name', 'Founded', 'Industry', 'Job Description',
#        'Job Title', 'Location', 'Rating', 'Revenue', 'Salary Estimate',
#        'Sector', 'Size', 'Type of ownership', 'hourly', 'currency',
#        'employer_provided', 'min_salary', 'max_salary', 'average_salary',
#        'company_txt', 'job_region-state', 'age', 'python_yn', 'r_studio_yn',
#        'sql_yn', 'cloud_yn', 'excel_yn', 'bigquery_yn', 'spark_yn',
#        'job_simpl', 'seniority', 'desc_len'],
#       dtype='object')

# %%
df_cat = df[['Location', 'Size', 'Type of ownership', 'Industry', 'Sector',
    'Revenue', 'company_txt', 'job_region-state','python_yn', 'r_studio_yn', 'sql_yn',
       'cloud_yn', 'excel_yn', 'bigquery_yn', 'spark_yn', 'job_simpl',
       'seniority']]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x= cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation = 90)
    plt.show()
# Out:
# graph for Location: total = 182
# graph for Size: total = 9
# graph for Type of ownership: total = 12
# graph for Industry: total = 64
# graph for Sector: total = 24
# graph for Revenue: total = 14
# graph for company_txt: total = 439
# graph for job_region-state: total = 71
# graph for python_yn: total = 2
# graph for r_studio_yn: total = 2
# graph for sql_yn: total = 2
# graph for cloud_yn: total = 2
# graph for excel_yn: total = 2
# graph for bigquery_yn: total = 2
# graph for spark_yn: total = 2
# graph for job_simpl: total = 7
# graph for seniority: total = 3

# %%
for i in df_cat[['Location','company_txt']].columns:
    cat_num = df_cat[i].value_counts()[:20]
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x= cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation = 90)
    plt.show()
# Out:
# graph for Location: total = 20
# graph for company_txt: total = 20

# %% [markdown]
# ###  Salary vs. various features using pivot tables

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Company Name', 'Founded', 'Industry', 'Job Description',
#        'Job Title', 'Location', 'Rating', 'Revenue', 'Salary Estimate',
#        'Sector', 'Size', 'Type of ownership', 'hourly', 'currency',
#        'employer_provided', 'min_salary', 'max_salary', 'average_salary',
#        'company_txt', 'job_region-state', 'age', 'python_yn', 'r_studio_yn',
#        'sql_yn', 'cloud_yn', 'excel_yn', 'bigquery_yn', 'spark_yn',
#        'job_simpl', 'seniority', 'desc_len'],
#       dtype='object')

# %%
pd.pivot_table(df, index =['job_simpl', 'seniority'], values = 'average_salary')
# Out:
#                           average_salary
# job_simpl      seniority
# analyst        na              60.156977
#                senior          83.000000
# data engineer  na              90.851852
#                senior         103.714286
# data scientist jr              53.000000
#                na              96.357456
#                senior         123.126016
# director       na             142.666667
# manager        na              89.600000
#                senior          50.500000
# mle            na              85.166667
# na             jr              72.500000
#                na              79.050000
#                senior          97.852941

# %%
pd.pivot_table(df, index =['job_region-state', 'job_simpl'], values = 'average_salary', aggfunc = 'count').sort_values('job_region-state', ascending = False)
# Out:
#                                  average_salary
# job_region-state job_simpl
# Winnipeg         mle                          2
#                  data scientist               4
# Welwyn           data scientist               2
# Waterloo         data scientist               1
# Victoria         data scientist               1
#                  analyst                      4
# Vernon           analyst                      1
# Venice           data scientist               1
# Vaughan          data scientist               1
# Vancouver        na                           6
#                  mle                          2
#                  data scientist              27
#                  data engineer                6
#                  analyst                     10
# Toronto          manager                      1
#                  analyst                     28
#                  data scientist              48
#                  data engineer               11
#                  mle                          9
#                  na                          10
# Surrey           analyst                      1
# Sioux Lookout    analyst                      1
# Saskatoon        data scientist               1
# Saint-Laurent    na                           2
#                  mle                          1
#                  analyst                      4
# Regina           data scientist               1
# Quebec           data scientist               2
# Pointe-Claire    data scientist               2
# Ottawa           mle                          1
# ...                                         ...
#  KS              na                           1
#  IN              na                           1
#                  data scientist               1
#                  data engineer                1
#                  analyst                      3
#  IL              data scientist               5
#                  analyst                      1
#  ID              na                           1
#                  data engineer                1
#  GA              data scientist               8
#                  data engineer                2
#  FL              na                           2
#                  data scientist               6
#                  data engineer                1
#                  analyst                      2
#  DC              data scientist              11
#                  data engineer                1
#                  analyst                      1
#  CT              na                           3
#                  data scientist               1
#  CO              na                           2
#                  data scientist               6
#  CA              director                     1
#                  data scientist              40
#                  analyst                      1
#                  mle                          2
#                  na                          18
#                  data engineer                3
#  AZ              data scientist               2
#  AL              na                           1
#
# [161 rows x 1 columns]

# %%
pd.pivot_table(df[df.job_simpl == 'data scientist'], index =['job_region-state'], values = 'average_salary').sort_values('average_salary', ascending = False)
# Out:
#                   average_salary
# job_region-state
#  CA                   147.475000
#  NY                   140.705882
#  WA                   139.000000
#  NJ                   124.800000
#  MA                   123.208333
#  IL                   120.000000
# Cochin                118.000000
#  VA                   116.676471
# Venice                116.000000
#  GA                   112.125000
#  FL                   109.416667
#  WI                   108.333333
#  MD                   107.500000
#  DC                   107.136364
# Victoria              107.000000
#  OH                   106.500000
#  AZ                   104.500000
# Vancouver             103.537037
#  PA                   102.833333
#  TN                   102.500000
# Welwyn                100.000000
# Mississauga            99.833333
#  UT                    99.437500
# Oakville               98.833333
#  MO                    97.100000
#  CO                    97.083333
#  TX                    96.666667
# London                 94.500000
#  KY                    94.000000
# Ottawa                 93.000000
# Toronto                92.500000
#  NM                    90.000000
#  NC                    89.000000
# Edmonton               88.875000
# Vaughan                87.500000
#  CT                    86.500000
# Markham                85.500000
#  ME                    85.250000
# Regina                 85.000000
# Calgary                84.416667
# North York             84.000000
# Montreal               80.340909
# Burnaby                80.000000
# Brampton               79.166667
# Quebec                 77.000000
# Pointe-Claire          76.500000
# Moncton                76.500000
# Saskatoon              74.500000
# Winnipeg               69.000000
# Waterloo               66.000000
# Burlington             62.500000
#  IN                    61.500000
# Dartmouth              51.500000

# %%
df.columns
df.to_csv('salary_data_cleaned.csv', index = False)

# %%
pd.read_csv('salary_data_cleaned.csv')
# Out:
#      Unnamed: 0                                       Company Name  Founded  \
# 0             0                 Raytheon Missiles & Defense\r\n3.8     2020
# 1             1                                      Humana\r\n3.9     1961
# 2             2                                 AstraZeneca\r\n4.2     1913
# 3             3                                 AstraZeneca\r\n4.2     1913
# 4             4                                  BankUnited\r\n2.9     2009
# 5             5                                        Unum\r\n3.9     1848
# 6             6                     Farm Credit Mid-America\r\n4.1     1985
# 7             7  Johns Hopkins Applied Physics Laboratory (APL)...     1942
# 8             8                        Myriad Genetics, Inc\r\n4.0     1991
# 9             9                                       GEICO\r\n3.5     1936
# 10           10                             Trinity Biotech\r\n2.7       -1
# 11           11                               Tivity Health\r\n2.8     1981
# 12           12                                      Humana\r\n3.9     1961
# 13           13                   Catalent Pharma Solutions\r\n3.3     2007
# 14           14                                       GEICO\r\n3.5     1936
# 15           15           Intuitive Research and Technology\r\n4.4     1999
# 16           16                                 Benson Hill\r\n3.0     2012
# 17           17                                     Enverus\r\n3.7     1999
# 18           18                      Intelligent Automation\r\n3.7     1987
# 19           19                                     Blucora\r\n3.4     1996
# 20           20                   BioFire Diagnostics, LLC.\r\n3.7     1990
# 21           21                                       Avant\r\n3.2     2012
# 22           22                                  Akima, LLC\r\n3.4     2003
# 23           23                            Northrop Grumman\r\n3.9     1939
# 24           24                     Laticrete International\r\n3.5       -1
# 25           25                            Northrop Grumman\r\n3.9     1939
# 26           26                         United Therapeutics\r\n3.5     1996
# 27           27                                     Buckman\r\n3.8     1945
# 28           28    Assured Information Security, Inc. (AIS)\r\n4.4     2001
# 29           29                                     Waystar\r\n3.9       -1
# ..          ...                                                ...      ...
# 628         628                       Renaissance BioScience Corp.       -1
# 629         629                                  NanoXplore\r\n4.0       -1
# 630         630              Government of British Columbia\r\n3.9     1858
# 631         631        Provincial Health Services Authority\r\n3.7     2001
# 632         632                                    CAE Inc.\r\n3.8     1947
# 633         633                Amazon Dev Centre Canada ULC\r\n3.9     1994
# 634         634                                     Uplight\r\n3.3       -1
# 635         635                                       CDLSI\r\n2.6       -1
# 636         636                          ZeniMax Media Inc.\r\n3.5     1999
# 637         637                                    agileDSS\r\n4.4     2005
# 638         638                                       Onica\r\n4.3     2017
# 639         639                                     Aerotek\r\n3.5     1983
# 640         640                                      Kainos\r\n4.2     1986
# 641         641                                Rocket Homes\r\n4.7     2006
# 642         642                   IT IQ TECH RECRUITERS LTD\r\n3.4     2002
# 643         643                                  O2E Brands\r\n4.2     2014
# 644         644                                  Savormetrics Inc.       -1
# 645         645           Sunnybrook Health Sciences Centre\r\n4.4     1948
# 646         646                                    CaseWare\r\n3.5     1988
# 647         647                                Global Relay\r\n3.5     1999
# 648         648                   IT IQ TECH RECRUITERS LTD\r\n3.4     2002
# 649         649                                  O2E Brands\r\n4.2     2014
# 650         650                                  Savormetrics Inc.       -1
# 651         651                  SynergyAspen Environmental\r\n5.0       -1
# 652         652                                    CaseWare\r\n3.5     1988
# 653         653      Centre for Addiction and Mental Health\r\n3.4       -1
# 654         654                                      Tucows\r\n3.6     1993
# 655         655        Provincial Health Services Authority\r\n3.7     2001
# 656         656                                     AVANADE\r\n4.0     2000
# 657         657                                      Tecsys\r\n3.9     1983
#
#                                     Industry  \
# 0                        Aerospace & Defense
# 1                         Insurance Carriers
# 2                  Biotech & Pharmaceuticals
# 3                  Biotech & Pharmaceuticals
# 4                      Banks & Credit Unions
# 5                         Insurance Carriers
# 6                                    Lending
# 7                        Aerospace & Defense
# 8                  Biotech & Pharmaceuticals
# 9                         Insurance Carriers
# 10                 Biotech & Pharmaceuticals
# 11          Health Care Services & Hospitals
# 12                        Insurance Carriers
# 13                 Biotech & Pharmaceuticals
# 14                        Insurance Carriers
# 15                       Aerospace & Defense
# 16                 Biotech & Pharmaceuticals
# 17                                    Energy
# 18                 Health, Beauty, & Fitness
# 19          Financial Transaction Processing
# 20                 Biotech & Pharmaceuticals
# 21                                   Lending
# 22                       Aerospace & Defense
# 23                       Aerospace & Defense
# 24                    Chemical Manufacturing
# 25                       Aerospace & Defense
# 26                 Biotech & Pharmaceuticals
# 27                    Chemical Manufacturing
# 28              Computer Hardware & Software
# 29   Enterprise Software & Network Solutions
# ..                                       ...
# 628                                       -1
# 629                                       -1
# 630                         Federal Agencies
# 631         Health Care Services & Hospitals
# 632                      Aerospace & Defense
# 633                                 Internet
# 634                                       -1
# 635                                       -1
# 636                              Video Games
# 637                              IT Services
# 638                              IT Services
# 639                   Staffing & Outsourcing
# 640                              IT Services
# 641                              Real Estate
# 642                   Staffing & Outsourcing
# 643                    Self-Storage Services
# 644                                       -1
# 645         Health Care Services & Hospitals
# 646             Computer Hardware & Software
# 647             Computer Hardware & Software
# 648                   Staffing & Outsourcing
# 649                    Self-Storage Services
# 650                                       -1
# 651                                       -1
# 652             Computer Hardware & Software
# 653         Health Care Services & Hospitals
# 654                              IT Services
# 655         Health Care Services & Hospitals
# 656                              IT Services
# 657  Enterprise Software & Network Solutions
#
#                                        Job Description  \
# 0    Senior Data Scientist\r\nRaytheon Missiles & D...
# 1    Description\r\nDigital Health and Analytics wi...
# 2    Do you have a passion for Science? Would you l...
# 3    Research Scientist/ Senior Research Scientist\...
# 4    Summary: The FCC Analytics group is responsibl...
# 5    Job Posting End Date: 12/24\r\nUnum is a compa...
# 6    At Farm Credit Mid-America, we believe people ...
# 7    Are you passionate about providing real impact...
# 8    Location: Salt Lake City, UT, United States\r\...
# 9    The Data Consumption team of Decision Sciences...
# 10   Immco Diagnostics is seeking a dynamic Clinica...
# 11   Description/Responsibilities\r\n\r\n\r\nPositi...
# 12   Description\r\nThe Lead Data Scientist uses ma...
# 13   Position Overview:\r\nCatalent hires people wi...
# 14   Working out of our Chevy Chase, MD/Washington ...
# 15   Data Scientist - Fort Walton Beach, FL\r\nLoca...
# 16   Benson Hill empowers innovators to develop mor...
# 17   Sr. Data Scientist\r\n\r\nWhy YOU want this po...
# 18   IAI is looking for a talented research scienti...
# 19   Blucora has a bold aspiration: we are committe...
# 20   BioFire Diagnostics is a global leader in deve...
# 21   Avant is dedicated to building premier digital...
# 22   Tuvli, an Akima Company, is dedicated to provi...
# 23   Embark on a career putting innovative, reliabl...
# 24   Classification:\r\nSalary\r\nJob Description:\...
# 25   Start your future with a new mission: Northrop...
# 26   What we do\r\nAbout United Therapeutics\r\nUni...
# 27   Data Scientist\r\n\r\nLanguage: English\r\n\r\...
# 28   AIS has a workshare opportunity for a Data Sci...
# 29   Waystar modernizes the healthcare revenue cycl...
# ..                                                 ...
# 628  Career Opportunity - Research Scientist – Ento...
# 629  NanoXplore est une entreprise de graphne, un m...
# 630  Senior Data Analyst\r\nResearch Officer R24\r\...
# 631  Data Analyst Health Surveillance\r\n\r\nEpidem...
# 632  Role and Responsibilities\r\nJob Description\r...
# 633  BS degree and 6 years of relevant experience o...
# 634  The Position\r\n\r\nDo you dream about creatin...
# 635  Title: Bilingual Call Center, Data Analyst\r\n...
# 636  Your Privacy:\r\nZeniMax understands the impor...
# 637  Nous sommes à la recherche d’un(e) Data Engine...
# 638  As a full spectrum AWS integrator, we assist h...
# 639  Our client, a regulatory group within one of t...
# 640  Our people love the exciting and meaningful wo...
# 641  Preferred Qualifications\r\nBachelor’s degree ...
# 642  IT/IQ Tech Recruiters is seeking a Data Analys...
# 643  Who we are:\r\n\r\nWith our uniquely branded h...
# 644  Machine Learning Engineer\r\nSavormetrics Inc\...
# 645  Apply for position\r\n\r\nScientist in Physica...
# 646  [Haven’t heard of us? That’s ok - ask your CPA...
# 647  As a Senior Data Scientist in the Analytics gr...
# 648  IT/IQ Tech Recruiters is seeking a Data Analys...
# 649  Who we are:\r\n\r\nWith our uniquely branded h...
# 650  Machine Learning Engineer\r\nSavormetrics Inc\...
# 651  POSITION OVERVIEW\r\nThe primary function of t...
# 652  [Haven’t heard of us? That’s ok - ask your CPA...
# 653  Job Number: 868007\r\nCategory: Research\r\nPo...
# 654  Tucows has been working on the Internet since ...
# 655  Data Analyst Health Surveillance\r\n\r\nEpidem...
# 656  Country:\r\nCanada\r\n\r\nCities:\r\nEdmonton,...
# 657  Analyste des données – Services partagés\r\n\r...
#
#                                              Job Title  \
# 0           Senior Data Scientist , Advanced Analytics
# 1                                     Data Scientist 2
# 2                 Scientist - Antibody Drug Conjugates
# 3        Research Scientist/ Senior Research Scientist
# 4                                   FCC Data Scientist
# 5                                       Data Scientist
# 6                                       Data Scientist
# 7                                       Data Scientist
# 8                                          Scientist I
# 9                              Spark/Big Data Engineer
# 10   Clinical Laboratory Scientist - HLA and Immuno...
# 11                        Data Scientist - Nutrisystem
# 12                                 Lead Data Scientist
# 13                                Analytical Scientist
# 14                                      Data Scientist
# 15                                      Data Scientist
# 16                              Genomic Data Scientist
# 17                                  Sr. Data Scientist
# 18                             Research Data Scientist
# 19                                   Data Scientist II
# 20                      Bioinformatics Staff Scientist
# 21                                      Data Scientist
# 22                     Data Scientist (TS/SCI cleared)
# 23                            Associate Data Scientist
# 24                                           Scientist
# 25                                      Data Scientist
# 26                       Product Development Scientist
# 27                                      Data Scientist
# 28                                      Data Scientist
# 29                                 Lead Data Scientist
# ..                                                 ...
# 628                    Research Scientist – Entomology
# 629  Chercheur scientifique Batterie / Research Sci...
# 630                    RES O 24R - Senior Data Analyst
# 631  Data Analyst Health Surveillance - BC Centre f...
# 632  Analyste de données de l’expérience client /Cu...
# 633  Senior Data Scientist, AWS Security- Ottawa/To...
# 634                           Data Engineer Contractor
# 635                Bilingual Call Center, Data Analyst
# 636  Spécialiste en Analyse des données / Data Analyst
# 637                       Data Engineer / Data Analyst
# 638                             Data Science Architect
# 639                               Fenergo Data Analyst
# 640                 Workday Financials Data Consultant
# 641                         Big Data Engineer--Toronto
# 642                               Data Analyst - 14906
# 643                         Data Engineer - O2E Brands
# 644                          Machine Learning Engineer
# 645  Scientist in Physical Sciences and Canada Rese...
# 646  Developer III, Data Analytics (Spring/Python/A...
# 647                              Senior Data Scientist
# 648                               Data Analyst - 14906
# 649                         Data Engineer - O2E Brands
# 650                          Machine Learning Engineer
# 651                     - Environmental Lead Scientist
# 652  Developer III, Data Analytics (Spring/Python/A...
# 653                        Brain Imaging Data Engineer
# 654                       Senior Data Analyst - Remote
# 655  Data Analyst Health Surveillance - BC Centre f...
# 656                         Data Engineer (Full Stack)
# 657                 Data Analyst / Analyste de données
#
#                        Location  Rating                           Revenue  \
# 0                   Andover, MA     3.8                $10+ billion (USD)
# 1                Louisville, KY     3.9                $10+ billion (USD)
# 2              Gaithersburg, MD     4.2                $10+ billion (USD)
# 3              Gaithersburg, MD     4.2                $10+ billion (USD)
# 4               Miami Lakes, FL     2.9                $10+ billion (USD)
# 5                  Portland, ME     3.9                $10+ billion (USD)
# 6                Louisville, KY     4.1        $100 to $500 million (USD)
# 7                    Laurel, MD     4.6            $1 to $2 billion (USD)
# 8            Salt Lake City, UT     4.0  $500 million to $1 billion (USD)
# 9               Chevy Chase, MD     3.5                $10+ billion (USD)
# 10                  Buffalo, NY     2.7         $50 to $100 million (USD)
# 11          Fort Washington, PA     2.8          Unknown / Non-Applicable
# 12                   Boston, MA     3.9                $10+ billion (USD)
# 13               Winchester, KY     3.3            $2 to $5 billion (USD)
# 14              Chevy Chase, MD     3.5                $10+ billion (USD)
# 15        Fort Walton Beach, FL     4.4        $100 to $500 million (USD)
# 16              Saint Louis, MO     3.0            $1 to $5 million (USD)
# 17             Conshohocken, PA     3.7        $100 to $500 million (USD)
# 18                Rockville, MD     3.7          $25 to $50 million (USD)
# 19                   Dallas, TX     3.4  $500 million to $1 billion (USD)
# 20           Salt Lake City, UT     3.7        $100 to $500 million (USD)
# 21                  Chicago, IL     3.2          Unknown / Non-Applicable
# 22               Washington, DC     3.4            $1 to $2 billion (USD)
# 23                 Hill AFB, UT     3.9                $10+ billion (USD)
# 24            Grand Prairie, TX     3.5        $100 to $500 million (USD)
# 25                 Hill AFB, UT     3.9                $10+ billion (USD)
# 26   Research Triangle Park, NC     3.5            $1 to $2 billion (USD)
# 27                  Memphis, TN     3.8  $500 million to $1 billion (USD)
# 28               Fort Meade, MD     4.4        $100 to $500 million (USD)
# 29                   Denver, CO     3.9          Unknown / Non-Applicable
# ..                          ...     ...                               ...
# 628                   Vancouver    -1.0                                -1
# 629                    Montreal     4.0        Less than $1 million (USD)
# 630                    Victoria     3.9                $10+ billion (USD)
# 631                   Vancouver     3.7          Unknown / Non-Applicable
# 632               Saint-Laurent     3.8            $2 to $5 billion (USD)
# 633                      Ottawa     3.9                $10+ billion (USD)
# 634                   Vancouver     3.3        Less than $1 million (USD)
# 635                     Toronto     2.6        Less than $1 million (USD)
# 636                    Montreal     3.5          Unknown / Non-Applicable
# 637                    Montreal     4.4          $10 to $25 million (USD)
# 638                     Toronto     4.3          Unknown / Non-Applicable
# 639                     Toronto     3.5          Unknown / Non-Applicable
# 640                     Toronto     4.2        $100 to $500 million (USD)
# 641                     Toronto     4.7          Unknown / Non-Applicable
# 642                   Vancouver     3.4          $25 to $50 million (USD)
# 643                   Vancouver     4.2        $100 to $500 million (USD)
# 644                 Mississauga    -1.0                                -1
# 645                     Toronto     4.4          Unknown / Non-Applicable
# 646                     Toronto     3.5          Unknown / Non-Applicable
# 647                   Vancouver     3.5          $25 to $50 million (USD)
# 648                   Vancouver     3.4          $25 to $50 million (USD)
# 649                   Vancouver     4.2        $100 to $500 million (USD)
# 650                 Mississauga    -1.0                                -1
# 651               Fort St. John     5.0        Less than $1 million (USD)
# 652                     Toronto     3.5          Unknown / Non-Applicable
# 653                     Toronto     3.4        $100 to $500 million (USD)
# 654                     Toronto     3.6        $100 to $500 million (USD)
# 655                   Vancouver     3.7          Unknown / Non-Applicable
# 656                    Edmonton     4.0            $2 to $5 billion (USD)
# 657                    Montreal     3.9         $50 to $100 million (USD)
#
#                       Salary Estimate  ... python_yn r_studio_yn sql_yn  \
# 0        $123K-$199K (Glassdoor est.)  ...         1           0      0
# 1          $52K-$95K (Glassdoor est.)  ...         1           0      1
# 2         $61K-$123K (Glassdoor est.)  ...         0           0      0
# 3         $88K-$167K (Glassdoor est.)  ...         0           0      0
# 4         $73K-$121K (Glassdoor est.)  ...         1           0      1
# 5         $58K-$103K (Glassdoor est.)  ...         0           0      1
# 6         $87K-$142K (Glassdoor est.)  ...         0           0      1
# 7        $100K-$160K (Glassdoor est.)  ...         1           0      0
# 8          $36K-$83K (Glassdoor est.)  ...         0           0      0
# 9         $52K-$101K (Glassdoor est.)  ...         0           0      1
# 10   $18-$33 Per Hour(Glassdoor est.)  ...         0           0      0
# 11        $90K-$148K (Glassdoor est.)  ...         0           0      1
# 12        $94K-$155K (Glassdoor est.)  ...         0           0      0
# 13         $40K-$71K (Glassdoor est.)  ...         0           0      0
# 14        $69K-$113K (Glassdoor est.)  ...         1           0      1
# 15        $64K-$109K (Glassdoor est.)  ...         1           0      1
# 16        $66K-$111K (Glassdoor est.)  ...         1           0      0
# 17        $92K-$149K (Glassdoor est.)  ...         1           0      0
# 18        $72K-$120K (Glassdoor est.)  ...         1           0      0
# 19        $74K-$121K (Glassdoor est.)  ...         1           0      1
# 20        $70K-$115K (Glassdoor est.)  ...         1           0      0
# 21        $89K-$144K (Glassdoor est.)  ...         1           0      1
# 22        $75K-$126K (Glassdoor est.)  ...         1           0      1
# 23        $63K-$102K (Glassdoor est.)  ...         1           0      1
# 24        $51K-$108K (Glassdoor est.)  ...         0           0      0
# 25        $65K-$114K (Glassdoor est.)  ...         1           0      1
# 26         $11K-$96K (Glassdoor est.)  ...         0           0      0
# 27        $83K-$135K (Glassdoor est.)  ...         1           0      1
# 28        $93K-$152K (Glassdoor est.)  ...         1           0      1
# 29        $93K-$157K (Glassdoor est.)  ...         1           0      1
# ..                                ...  ...       ...         ...    ...
# 628    CA$50K-CA$90K (Glassdoor est.)  ...         0           0      0
# 629    CA$47K-CA$55K (Glassdoor est.)  ...         0           0      0
# 630    CA$76K-CA$96K (Glassdoor est.)  ...         0           0      0
# 631    CA$47K-CA$63K (Glassdoor est.)  ...         0           0      0
# 632    CA$47K-CA$65K (Glassdoor est.)  ...         1           0      1
# 633    CA$90K-CA$99K (Glassdoor est.)  ...         1           0      1
# 634   CA$80K-CA$100K (Glassdoor est.)  ...         1           0      1
# 635    CA$43K-CA$74K (Glassdoor est.)  ...         0           0      0
# 636    CA$37K-CA$51K (Glassdoor est.)  ...         1           0      1
# 637    CA$35K-CA$75K (Glassdoor est.)  ...         1           0      0
# 638   CA$71K-CA$120K (Glassdoor est.)  ...         1           0      1
# 639    CA$45K-CA$59K (Glassdoor est.)  ...         0           0      0
# 640   CA$65K-CA$102K (Glassdoor est.)  ...         0           0      0
# 641   CA$55K-CA$115K (Glassdoor est.)  ...         1           0      1
# 642    CA$52K-CA$76K (Glassdoor est.)  ...         0           0      0
# 643    CA$79K-CA$93K (Glassdoor est.)  ...         1           0      1
# 644   CA$71K-CA$115K (Glassdoor est.)  ...         1           0      0
# 645    CA$54K-CA$65K (Glassdoor est.)  ...         0           0      0
# 646    CA$55K-CA$59K (Glassdoor est.)  ...         1           0      0
# 647   CA$93K-CA$115K (Glassdoor est.)  ...         1           0      0
# 648    CA$52K-CA$76K (Glassdoor est.)  ...         0           0      0
# 649    CA$79K-CA$93K (Glassdoor est.)  ...         1           0      1
# 650   CA$71K-CA$115K (Glassdoor est.)  ...         1           0      0
# 651    CA$60K-CA$79K (Glassdoor est.)  ...         0           0      0
# 652    CA$55K-CA$59K (Glassdoor est.)  ...         1           0      0
# 653   CA$50K-CA$110K (Glassdoor est.)  ...         1           0      1
# 654    CA$80K-CA$91K (Glassdoor est.)  ...         1           0      1
# 655    CA$47K-CA$63K (Glassdoor est.)  ...         0           0      0
# 656   CA$80K-CA$115K (Glassdoor est.)  ...         1           0      1
# 657    CA$55K-CA$75K (Glassdoor est.)  ...         0           0      0
#
#      cloud_yn excel_yn  bigquery_yn  spark_yn       job_simpl  seniority  \
# 0           1        0            0         0  data scientist     senior
# 1           0        0            0         1  data scientist         na
# 2           0        0            0         0              na         na
# 3           0        1            0         0              na     senior
# 4           0        0            0         0  data scientist         na
# 5           0        1            0         0  data scientist         na
# 6           0        0            0         0  data scientist         na
# 7           0        1            0         0  data scientist         na
# 8           0        1            0         0              na         na
# 9           0        1            0         1   data engineer         na
# 10          0        0            0         0              na         na
# 11          1        1            1         0  data scientist         na
# 12          0        0            0         0  data scientist     senior
# 13          0        0            0         0              na         na
# 14          1        1            0         1  data scientist         na
# 15          0        1            0         0  data scientist         na
# 16          1        0            0         0  data scientist         na
# 17          0        0            0         1  data scientist     senior
# 18          0        1            0         1  data scientist         na
# 19          0        1            0         0  data scientist         na
# 20          1        1            0         0              na         na
# 21          0        0            0         0  data scientist         na
# 22          0        0            0         0  data scientist         na
# 23          0        0            0         0  data scientist         na
# 24          0        1            0         0              na         na
# 25          0        0            0         0  data scientist         na
# 26          0        1            0         0              na         na
# 27          1        0            0         0  data scientist         na
# 28          0        0            0         0  data scientist         na
# 29          0        0            0         0  data scientist     senior
# ..        ...      ...          ...       ...             ...        ...
# 628         0        0            0         0              na         na
# 629         0        1            0         0              na         na
# 630         0        0            0         0         analyst     senior
# 631         0        1            0         0         analyst         na
# 632         1        1            0         0         analyst         na
# 633         1        0            0         1  data scientist     senior
# 634         1        0            0         1   data engineer         na
# 635         0        1            0         0         analyst         na
# 636         1        1            0         1         analyst         na
# 637         1        0            0         1   data engineer         na
# 638         1        1            0         0              na         na
# 639         0        0            0         0         analyst         na
# 640         0        1            0         0              na         na
# 641         1        0            0         1   data engineer         na
# 642         0        0            0         0         analyst         na
# 643         1        1            0         0   data engineer         na
# 644         1        0            0         0             mle         na
# 645         0        1            0         0              na         na
# 646         1        1            0         1              na         na
# 647         0        0            0         0  data scientist     senior
# 648         0        0            0         0         analyst         na
# 649         1        1            0         0   data engineer         na
# 650         1        0            0         0             mle         na
# 651         0        1            0         0              na     senior
# 652         1        1            0         1              na         na
# 653         0        0            0         0   data engineer         na
# 654         0        1            0         0         analyst     senior
# 655         0        1            0         0         analyst         na
# 656         1        0            0         1   data engineer         na
# 657         0        1            0         0         analyst         na
#
#     desc_len
# 0       4667
# 1       3555
# 2       4703
# 3       5222
# 4       4843
# 5       5598
# 6       6609
# 7       2949
# 8       2972
# 9       4008
# 10      6252
# 11      4441
# 12      2244
# 13      6118
# 14      4771
# 15      4852
# 16      5673
# 17      2473
# 18      2921
# 19      4945
# 20      3535
# 21      3633
# 22      4972
# 23      3265
# 24      5332
# 25      3334
# 26      3775
# 27      3773
# 28      2277
# 29      3681
# ..       ...
# 628     7581
# 629     9114
# 630     6125
# 631     6283
# 632    10235
# 633     4644
# 634     2920
# 635     3486
# 636     7219
# 637     2711
# 638     6454
# 639     1810
# 640     5114
# 641     4430
# 642     3159
# 643     3522
# 644     4578
# 645    15432
# 646     6974
# 647     3231
# 648     3159
# 649     3522
# 650     4578
# 651     3076
# 652     6974
# 653     4895
# 654     3524
# 655     6283
# 656     4630
# 657     6013
#
# [658 rows x 32 columns]

# %%
# salary X rating, industry, sector, revenue, country, 
#hourly, employer provided, python, r, sql, cloud, excel, 
#bigquery, spark, desc_len, type of ownership

# %%
df_pivots = df[['Industry', 'Revenue', 'Rating', 'Sector', 'Size','Type of ownership', 
               'hourly', 'currency','employer_provided', 'job_region-state', 
                'python_yn','r_studio_yn','sql_yn','excel_yn','bigquery_yn', 
                'spark_yn', 'cloud_yn', 'average_salary']]

# %%
for i in df_pivots.columns:
    print(i)
    print(pd.pivot_table(df_pivots, index = i, values = 'average_salary').sort_values('average_salary', ascending = False))
# Out:
# Industry
#                                          average_salary
# Industry
# Transportation Equipment Manufacturing       138.250000
# Wholesale                                    126.666667
# Investment Banking & Asset Management        118.458333
# Metal & Mineral Manufacturing                115.000000
# Commercial Equipment Rental                  115.000000
# Financial Transaction Processing             114.500000
# Education Training Services                  113.800000
# Enterprise Software & Network Solutions      111.815789
# Internet                                     111.144737
# Municipal Governments                        109.500000
# Advertising & Marketing                      108.475000
# Publishing                                   105.666667
# Aerospace & Defense                          105.395349
# Computer Hardware & Software                 104.301887
# Other Retail Stores                          103.000000
# Accounting                                   102.800000
# Utilities                                    102.375000
# Consulting                                   101.037037
# Financial Analytics & Research               101.000000
# Logistics & Supply Chain                      98.666667
# Health, Beauty, & Fitness                     98.375000
# Lending                                       97.833333
# Consumer Products Manufacturing               96.500000
# Architectural & Engineering Services          96.500000
# Insurance Agencies & Brokerages               95.200000
# Video Games                                   95.150000
# Biotech & Pharmaceuticals                     94.630000
# IT Services                                   93.596774
# Insurance Carriers                            92.178571
# Fast-Food & Quick-Service Restaurants         91.000000
# ...                                                 ...
# Federal Agencies                              86.346154
# Rail                                          86.333333
# Banks & Credit Unions                         86.181818
# Self-Storage Services                         86.000000
# Social Assistance                             84.666667
# Chemical Manufacturing                        82.875000
# Real Estate                                   82.375000
# Building & Personnel Services                 81.500000
# Shipping                                      81.000000
# Hotels, Motels, & Resorts                     80.500000
# Industrial Manufacturing                      80.250000
# Vehicle Dealers                               78.500000
# Health Care Services & Hospitals              78.277778
# Colleges & Universities                       76.700000
# Cable, Internet & Telephone Providers         76.500000
# -1                                            73.313333
# Research & Development                        73.285714
# Staffing & Outsourcing                        73.250000
# Membership Organizations                      72.750000
# Electrical & Electronic Manufacturing         71.666667
# Audiovisual                                   69.000000
# Health Care Products Manufacturing            67.833333
# Miscellaneous Manufacturing                   67.500000
# Home Furniture & Housewares Stores            64.333333
# Transportation Management                     61.500000
# Express Delivery Services                     59.000000
# Bus Transportation Services                   55.000000
# Department, Clothing, & Shoe Stores           53.416667
# Grocery Stores & Supermarkets                 48.000000
# Food & Beverage Manufacturing                 47.000000
#
# [64 rows x 1 columns]
# Revenue
#                                   average_salary
# Revenue
# $1 to $5 million (USD)                108.000000
# $10+ billion (USD)                    102.708738
# Unknown / Non-Applicable              100.445714
# $10 to $25 million (USD)               96.607143
# $100 to $500 million (USD)             94.873418
# $5 to $10 billion (USD)                93.724138
# $25 to $50 million (USD)               88.687500
# $50 to $100 million (USD)              88.597222
# $500 million to $1 billion (USD)       88.379310
# $2 to $5 billion (USD)                 86.827586
# $1 to $2 billion (USD)                 86.093750
# $5 to $10 million (USD)                85.750000
# Less than $1 million (USD)             73.800000
# -1                                     70.516129
# Rating
#         average_salary
# Rating
#  4.3        108.195652
#  4.8        106.916667
#  3.9        105.405660
#  4.2        105.333333
#  3.8        104.987179
#  4.7        101.250000
#  2.2        100.000000
#  4.1         99.590909
#  4.9         99.500000
#  3.6         98.805556
#  4.5         97.733333
#  4.6         96.261905
#  4.0         95.000000
#  4.4         94.870370
#  3.5         93.914894
#  3.1         90.458333
#  3.7         90.255319
#  2.8         90.000000
#  3.4         89.568182
#  3.3         88.727273
#  2.4         85.500000
#  2.7         79.611111
#  3.2         78.583333
#  3.0         78.500000
#  2.0         77.500000
#  5.0         75.294118
# -1.0         73.829268
#  2.5         67.500000
#  2.9         66.785714
#  1.8         58.500000
#  1.0         54.000000
#  2.6         51.625000
# Sector
#                                    average_salary
# Sector
# Information Technology                 105.637500
# Aerospace & Defense                    105.395349
# Accounting & Legal                     102.800000
# Finance                                102.250000
# Media                                   99.093750
# Education                               95.250000
# Biotech & Pharmaceuticals               94.630000
# Consumer Services                       94.250000
# Oil, Gas, Energy & Utilities            94.038462
# Insurance                               92.636364
# Business Services                       91.686170
# Restaurants, Bars & Food Services       91.000000
# Mining & Metals                         90.833333
# Government                              89.433333
# Manufacturing                           86.096154
# Telecommunications                      85.083333
# Non-Profit                              84.666667
# Transportation & Logistics              84.550000
# Real Estate                             82.375000
# Health Care                             78.277778
# -1                                      73.313333
# Arts, Entertainment & Recreation        69.000000
# Travel & Tourism                        67.750000
# Retail                                  65.076923
# Size
#                          average_salary
# Size
# 201 to 500 Employees          99.287879
# 51 to 200 Employees           98.633333
# 10000+ Employees              96.980892
# 1001 to 5000 Employees        96.366337
# 5001 to 10000 Employees       92.989796
# 501 to 1000 Employees         88.592308
# 1 to 50 Employees             80.346154
# Unknown                       76.678571
# -1                            70.516129
# Type of ownership
#                                 average_salary
# Type of ownership
# Other Organization                  103.142857
# Company - Public                     97.256281
# Company - Private                    95.551887
# Subsidiary or Business Segment       91.875000
# Unknown                              88.214286
# Private Practice / Firm              86.500000
# Nonprofit Organization               85.500000
# Government                           82.769231
# College / University                 76.700000
# Hospital                             76.115385
# -1                                   70.516129
# Contract                             65.000000
# hourly
#         average_salary
# hourly
# 0            94.038402
# 1            28.428571
# currency
#           average_salary
# currency
# US            105.889728
# CAD            80.637615
# employer_provided
#                    average_salary
# employer_provided
# 0                       93.340426
# job_region-state
#                   average_salary
# job_region-state
#  MN                   138.833333
#  NY                   131.809524
#  CA                   131.130769
#  WA                   125.000000
# Venice                116.000000
#  MA                   112.218750
#  NJ                   112.200000
#  IL                   109.666667
#  GA                   109.550000
#  VA                   107.592593
#  MD                   105.140625
#  DC                   104.884615
#  AZ                   104.500000
# Welwyn                100.000000
#  MO                    99.166667
# Oakville               97.166667
#  FL                    96.090909
#  PA                    95.777778
#  ID                    95.500000
#  UT                    94.083333
# Vancouver              94.019608
#  TX                    91.750000
#  CO                    90.062500
# Edmonton               89.687500
# Cochin                 89.000000
#  CT                    88.500000
# Vaughan                87.500000
# Mississauga            86.142857
# Ottawa                 85.433333
#  ME                    85.250000
# ...                          ...
# Moncton                76.500000
# Pointe-Claire          76.500000
# Victoria               75.300000
# Saskatoon              74.500000
# London                 74.500000
#  NM                    74.375000
# Guelph                 72.500000
#  NC                    71.750000
#  OH                    70.750000
# Surrey                 70.000000
# Montreal               69.611111
#  IN                    66.916667
# Waterloo               66.000000
# Laval                  63.250000
# Burlington             62.500000
#  AL                    62.000000
# Fort St. John          62.000000
#  SC                    62.000000
# Winnipeg               60.333333
# Sioux Lookout          60.000000
# Bedford                59.500000
# Halifax                59.166667
#  TN                    54.000000
#  MS                    53.000000
# Dartmouth              51.500000
# Vernon                 48.000000
# Saint-Laurent          45.214286
#  KS                    44.000000
# Kitchener              40.500000
# Chatham-Kent           40.500000
#
# [71 rows x 1 columns]
# python_yn
#            average_salary
# python_yn
# 1               99.335141
# 0               79.312183
# r_studio_yn
#              average_salary
# r_studio_yn
# 0                 93.459604
# 1                 54.250000
# sql_yn
#         average_salary
# sql_yn
# 1            98.026239
# 0            88.238095
# excel_yn
#           average_salary
# excel_yn
# 0              97.768212
# 1              89.584270
# bigquery_yn
#              average_salary
# bigquery_yn
# 1                115.970588
# 0                 92.740250
# spark_yn
#           average_salary
# spark_yn
# 1             101.186047
# 0              90.563786
# cloud_yn
#           average_salary
# cloud_yn
# 1              99.616505
# 0              90.480088
# average_salary
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-3588bf134bf3> in <module>
#       1 for i in df_pivots.columns:
#       2     print(i)
# ----> 3     print(pd.pivot_table(df_pivots, index = i, values = 'average_salary').sort_values('average_salary', ascending = False))
#
# D:\anaconda\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#      79         values = list(values)
#      80
# ---> 81     grouped = data.groupby(keys, observed=False)
#      82     agged = grouped.agg(aggfunc)
#      83     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#
# D:\anaconda\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7630         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    7631                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 7632                        observed=observed, **kwargs)
#    7633
#    7634     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# D:\anaconda\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2108         raise TypeError('invalid type: {}'.format(obj))
#    2109
# -> 2110     return klass(obj, by, **kwds)
#
# D:\anaconda\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     358                                                     sort=sort,
#     359                                                     observed=observed,
# --> 360                                                     mutated=self.mutated)
#     361
#     362         self.obj = obj
#
# D:\anaconda\lib\site-packages\pandas\core\groupby\grouper.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     600                          observed=observed,
#     601                          in_axis=in_axis)
# --> 602                 if not isinstance(gpr, Grouping) else gpr)
#     603
#     604         groupings.append(ping)
#
# D:\anaconda\lib\site-packages\pandas\core\groupby\grouper.py in __init__(self, index, grouper, obj, name, level, sort, observed, in_axis)
#     320                     t = self.name or str(type(self.grouper))
#     321                     raise ValueError(
# --> 322                         "Grouper for '{}' not 1-dimensional".format(t))
#     323                 self.grouper = self.index.map(self.grouper)
#     324                 if not (hasattr(self.grouper, "__len__") and
#
# ValueError: Grouper for 'average_salary' not 1-dimensional

# %%
pd.pivot_table(df_pivots, index = 'Revenue', columns = 'python_yn', values = 'average_salary', aggfunc = 'count')

# %% [markdown]
# ##### Word Cloud with the job desciption

# %%
#conda install -c conda-forge wordcloud=1.6.0 

from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    ''' remove punctuation and stop words'''
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        filtered.append(w.lower())
    return filtered

words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc = WordCloud(background_color='white', random_state=1,
               stopwords = STOPWORDS, max_words = 2000, width = 800, height = 1500)
wc.generate(text)

plt.figure(figsize = (10,10))
plt.imshow(wc, interpolation = 'bilinear')
plt.axis('off')
plt.show()
